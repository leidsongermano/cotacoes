# %% [markdown]
# #### Clusterização dos Usuários

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import pickle

colors = ['darkorange', 'darkgreen', 'royalblue', 'salmon', 'firebrick', 'darkgray', 'teal',
         'sandybrown', 'dodgerblue', 'crimson', 'gold', 'darkolivegreen', 'skyblue', 'mediumpurple',
         'indianred', 'darkcyan', 'chocolate', 'cornflowerblue', 'tan', 'darkblue'];

# %%
dados_historicos = pd.read_excel('Dados_historicos.xlsx')
dados_historicos.set_index('User', inplace = True)
dados_historicos.head()
# Out:
#        Habilidade 1  Habilidade 2  Habilidade 3  Habilidade 4  Habilidade 5  \
# User
# User1            87            92            46            54            68
# User2           100            59            22             1            83
# User3            95            86            14            53            16
# User4            79            41            52            27            82
# User5            91            20            91            40            40
#
#        Habilidade 6  Habilidade 7  Habilidade 8  Habilidade 9  Habilidade 10
# User
# User1            84             0            35             3             83
# User2            30            36            75             2             10
# User3            39            81             3            88             91
# User4            30            42            65            15             37
# User5            67            25            52            69             71

# %% [markdown]
# #### Escalonamento

# %%
scl = StandardScaler()
X = scl.fit_transform(dados_historicos)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %% [markdown]
# ##### Agrupamento K-Means

# %%
def kmeans(numero_de_clusters, dados):
  modelo = KMeans(n_clusters = numero_de_clusters)
  modelo.fit(dados)
  return [numero_de_clusters, modelo.inertia_]

# %%
qtd_grupos = [kmeans(n_clusters, X) for n_clusters in range(1, 50)]
qtd_grupos = pd.DataFrame(qtd_grupos, columns = ['n_clusters', 'inercia'])

# %%
plt.figure(figsize = [30,8])
plt.plot(qtd_grupos['n_clusters'], qtd_grupos['inercia'], color = 'firebrick', lw = 4)
plt.xticks(qtd_grupos['n_clusters'], rotation = 'vertical')
name = 'Método de Elbow'
plt.title(name)
plt.savefig(name+'.png', dpi = 300)
plt.show()

# %%
agrup = KMeans(n_clusters = 10, random_state=42).fit(X)
dados_historicos['Grupo_Geral'] = agrup.labels_

# %%
grupo = pd.DataFrame(agrup.cluster_centers_)

# %%
grupo.columns = dados_historicos.columns[0:10]

# %%
eixo = np.arange(10)

plt.rcParams['axes.prop_cycle']
colors = ['darkorange', 'darkgreen', 'royalblue', 'salmon', 'firebrick', 'darkgray', 'teal',
         'sandybrown', 'dodgerblue', 'crimson', 'gold', 'darkolivegreen', 'skyblue', 'mediumpurple',
         'indianred', 'darkcyan', 'chocolate', 'cornflowerblue', 'tan', 'darkblue']

for i in range(10):
    plt.figure(figsize = [30,8])
    plt.bar(eixo, grupo[grupo.index == i].values[0], color = colors[i])
    name = 'Grupo - '+str(i)
    plt.title(name)
    plt.xticks(eixo, grupo.columns, rotation = 'vertical')
    plt.savefig(name+'.png', dpi = 300)
    plt.show()

# %%
user = dados_historicos[dados_historicos.index == 'User42']

# %%
dados_historicos.to_json(orient = 'index')
# Out:
# '{"User1":{"Habilidade 1":87,"Habilidade 2":92,"Habilidade 3":46,"Habilidade 4":54,"Habilidade 5":68,"Habilidade 6":84,"Habilidade 7":0,"Habilidade 8":35,"Habilidade 9":3,"Habilidade 10":83,"Grupo_Geral":0},"User2":{"Habilidade 1":100,"Habilidade 2":59,"Habilidade 3":22,"Habilidade 4":1,"Habilidade 5":83,"Habilidade 6":30,"Habilidade 7":36,"Habilidade 8":75,"Habilidade 9":2,"Habilidade 10":10,"Grupo_Geral":1},"User3":{"Habilidade 1":95,"Habilidade 2":86,"Habilidade 3":14,"Habilidade 4":53,"Habilidade 5":16,"Habilidade 6":39,"Habilidade 7":81,"Habilidade 8":3,"Habilidade 9":88,"Habilidade 10":91,"Grupo_Geral":8},"User4":{"Habilidade 1":79,"Habilidade 2":41,"Habilidade 3":52,"Habilidade 4":27,"Habilidade 5":82,"Habilidade 6":30,"Habilidade 7":42,"Habilidade 8":65,"Habilidade 9":15,"Habilidade 10":37,"Grupo_Geral":1},"User5":{"Habilidade 1":91,"Habilidade 2":20,"Habilidade 3":91,"Habilidade 4":40,"Habilidade 5":40,"Habilidade 6":67,"Habilidade 7":25,"Habilidade 8":52,"Habilidade 9":69,"Habilidade 10":71,"Grupo_Geral":5},"User6":{"Habilidade 1":96,"Habilidade 2":96,"Habilidade 3":92,"Habilidade 4":57,"Habilidade 5":47,"Habilidade 6":96,"Habilidade 7":14,"Habilidade 8":25,"Habilidade 9":37,"Habilidade 10":8,"Grupo_Geral":5},"User7":{"Habilidade 1":42,"Habilidade 2":43,"Habilidade 3":55,"Habilidade 4":59,"Habilidade 5":35,"Habilidade 6":78,"Habilidade 7":70,"Habilidade 8":6,"Habilidade 9":97,"Habilidade 10":39,"Grupo_Geral":2},"User8":{"Habilidade 1":40,"Habilidade 2":76,"Habilidade 3":8,"Habilidade 4":49,"Habilidade 5":70,"Habilidade 6":70,"Habilidade 7":35,"Habilidade 8":43,"Habilidade 9":25,"Habilidade 10":92,"Grupo_Geral":0},"User9":{"Habilidade 1":32,"Habilidade 2":68,"Habilidade 3":36,"Habilidade 4":51,"Habilidade 5":87,"Habilidade 6":29,"Habilidade 7":35,"Habilidade 8":69,"Habilidade 9":85,"Habilidade 10":45,"Grupo_Geral":3},"User10":{"Habilidade 1":97,"Habilidade 2":51,"Habilidade 3":65,"Habilidade 4":5,"Habilidade 5":66,"Habilidade 6":43,"Habilidade 7":8,"Habilidade 8":73,"Habilidade 9":66,"Habilidade 10":53,"Grupo_Geral":3},"User11":{"Habilidade 1":13,"Habilidade 2":41,"Habilidade 3":30,"Habilidade 4":85,"Habilidade 5":83,"Habilidade 6":79,"Habilidade 7":19,"Habilidade 8":94,"Habilidade 9":100,"Habilidade 10":76,"Grupo_Geral":0},"User12":{"Habilidade 1":16,"Habilidade 2":86,"Habilidade 3":94,"Habilidade 4":12,"Habilidade 5":73,"Habilidade 6":50,"Habilidade 7":42,"Habilidade 8":75,"Habilidade 9":25,"Habilidade 10":36,"Grupo_Geral":6},"User13":{"Habilidade 1":2,"Habilidade 2":97,"Habilidade 3":26,"Habilidade 4":21,"Habilidade 5":76,"Habilidade 6":96,"Habilidade 7":34,"Habilidade 8":3,"Habilidade 9":12,"Habilidade 10":51,"Grupo_Geral":6},"User14":{"Habilidade 1":1,"Habilidade 2":54,"Habilidade 3":42,"Habilidade 4":62,"Habilidade 5":1,"Habilidade 6":73,"Habilidade 7":56,"Habilidade 8":77,"Habilidade 9":17,"Habilidade 10":15,"Grupo_Geral":9},"User15":{"Habilidade 1":92,"Habilidade 2":20,"Habilidade 3":89,"Habilidade 4":26,"Habilidade 5":23,"Habilidade 6":61,"Habilidade 7":37,"Habilidade 8":60,"Habilidade 9":49,"Habilidade 10":35,"Grupo_Geral":5},"User16":{"Habilidade 1":39,"Habilidade 2":6,"Habilidade 3":8,"Habilidade 4":77,"Habilidade 5":92,"Habilidade 6":9,"Habilidade 7":50,"Habilidade 8":21,"Habilidade 9":0,"Habilidade 10":10,"Grupo_Geral":1},"User17":{"Habilidade 1":96,"Habilidade 2":93,"Habilidade 3":16,"Habilidade 4":88,"Habilidade 5":10,"Habilidade 6":90,"Habilidade 7":98,"Habilidade 8":14,"Habilidade 9":97,"Habilidade 10":32,"Grupo_Geral":2},"User18":{"Habilidade 1":41,"Habilidade 2":100,"Habilidade 3":24,"Habilidade 4":68,"Habilidade 5":7,"Habilidade 6":53,"Habilidade 7":15,"Habilidade 8":100,"Habilidade 9":72,"Habilidade 10":32,"Grupo_Geral":9},"User19":{"Habilidade 1":69,"Habilidade 2":32,"Habilidade 3":39,"Habilidade 4":100,"Habilidade 5":14,"Habilidade 6":26,"Habilidade 7":95,"Habilidade 8":93,"Habilidade 9":11,"Habilidade 10":17,"Grupo_Geral":9},"User20":{"Habilidade 1":38,"Habilidade 2":65,"Habilidade 3":52,"Habi ...

# %% [markdown]
# #### Exportação do Scaler

# %%
pickle.dump(scl, open('escala_agrup.m', 'wb'))

# %%
pickle.dump(agrup, open('agrupamento.m', 'wb'))
